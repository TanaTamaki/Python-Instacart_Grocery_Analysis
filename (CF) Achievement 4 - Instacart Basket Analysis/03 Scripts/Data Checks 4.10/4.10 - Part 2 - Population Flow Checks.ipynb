# %%
import pandas as pd
import numpy as np
import os

# %%
# Creating a path to project folder.

path = r'C:\Users\TanaT\(CF) Achievement 4 - Instacart Basket Analysis'

# %%
# Importing orders original data

df_ords_original = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'))

# %%
# Shape of original orders data 
df_ords_original.shape
# Out:
# (3421083, 7)

# %%
# Importing cleaned orders data
df_ords_clean = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'cleaned_orders_data.csv'))

# %%
# Shape of cleaned orders data
df_ords_clean.shape
# Out:
# (3421083, 7)

# %%
# Importing orders products prior original
df_ords_prod_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders_products_prior.csv'))

# %%
# Shape
df_ords_prod_prior.shape
# Out:
# (32434489, 4)

# %%
# Importing products original data
df_products = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'))

# %%
# Shape 
df_products.shape
# Out:
# (49693, 5)

# %%
# Importing cleaned products data
df_cleaned_prod = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'cleaned_products_data.csv'))

# %%
# Shape 
df_cleaned_prod.shape
# Out:
# (49672, 6)

# %%
# Importing customers orginal data
df_cust = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'))

# %%
# Shape 
df_cust.shape
# Out:
# (206209, 10)

# %%
# Importing orders wrangled for crosstab
df_first_order_check = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'))

# %%
df_first_order_check.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           1   2398795        1             2                   3
# 2           2    473747        1             3                   3
# 3           3   2254736        1             4                   4
# 4           4    431534        1             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
df_first_order_check.drop('Unnamed: 0', axis=1, inplace=True)
df_first_order_check.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Crosstab to check missing (NaN are all due to first orders = order number should be 1)

crosstab_check = pd.crosstab(df_first_order_check['days_since_prior_order'], df_first_order_check['order_number'], dropna = False)
crosstab_check
# Out:
# order_number               1      2      3      4      5      6      7    \
# days_since_prior_order
# 0.0                          0   2899   2915   2964   2634   2443   2236
# 1.0                          0   4822   4613   4690   4423   4047   4000
# 2.0                          0   6203   6209   6231   5789   5679   5274
# 3.0                          0   7411   7577   7414   7097   6770   6424
# 4.0                          0   8415   8476   8469   8029   7608   7092
# 5.0                          0   9216   9329   9220   8600   8228   7703
# 6.0                          0  11419  11701  11601  10771  10054   9521
# 7.0                          0  16788  16609  16341  15135  13834  13268
# 8.0                          0  10422  10304  10148   9378   8738   8068
# 9.0                          0   7053   7160   7013   6610   5993   5497
# 10.0                         0   5969   6037   5938   5376   5018   4479
# ...

# %%
crosstab_check.to_clipboard()
